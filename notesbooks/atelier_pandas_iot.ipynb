# %% [markdown]
# Partie 1 – Series
# 1) Créer une Series contenant 4 températures

# %%
import pandas as pd
temperature = pd.Series([34.5, 23.4, 19.8, 34.2])
temperature
# Out:
# 0    34.5
# 1    23.4
# 2    19.8
# 3    34.2
# dtype: float64

# %% [markdown]
# 2) afficher son index

# %%
print(temperature.index)
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %% [markdown]
# 3) Afficher la 1ère valeur

# %%
print(temperature[0])
# Out:
# 34.5
